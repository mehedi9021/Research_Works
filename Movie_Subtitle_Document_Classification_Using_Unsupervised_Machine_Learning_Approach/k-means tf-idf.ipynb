# %%
# importing libraries
import nltk
import re
from urllib import request
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pandas as pd


#Data preparation and preprocess
def custom_preprocessor(text):
        text = re.sub(r'\W+|\d+|_', ' ', text)    #removing numbers and punctuations
        text =  re.sub(r'\s+',' ',text) #remove multiple spaces into a single space
        text = re.sub(r"\s+[a-zA-Z]\s+",' ',text) #remove a single character
        text = text.lower()
        text = nltk.word_tokenize(text)       #tokenizing
        text = [word for word in text if not word in stop_words] #English Stopwords
        text = [lemmatizer.lemmatize(word) for word in text]              #Lemmatising
        return text



filepath_dict = {'Book1':   'https://github.com/mehedi9021/Txt/blob/main/b1.txt',
                 'Book2': 'https://github.com/mehedi9021/Txt/blob/main/b2.txt',
                 'Book3':   'https://github.com/mehedi9021/Txt/blob/main/b2.txt',
                 'Book4':   'https://github.com/mehedi9021/Txt/blob/main/b1.txt',
                'Book5':   'https://github.com/mehedi9021/Txt/blob/main/b1.txt',
                 'Book6': 'https://github.com/mehedi9021/Txt/blob/main/b1.txt',
                 'Book7':   'https://github.com/mehedi9021/Txt/blob/main/b2.txt',
                'Book8':   'https://github.com/mehedi9021/Txt/blob/main/b1.txt',
                 'Book9': 'https://github.com/mehedi9021/Txt/blob/main/b1.txt',
                 'Book10':   'https://github.com/mehedi9021/Txt/blob/main/b2.txt',
                'Book11':   'https://github.com/mehedi9021/Txt/blob/main/b2.txt'}


for key, value in filepath_dict.items():
   if (key == "Book1"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        first_book = custom_preprocessor(raw)
   elif (key == "Book2"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        second_book = custom_preprocessor(raw)
   elif (key == "Book3"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        third_book = custom_preprocessor(raw)
   elif (key == "Book4"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        four_book = custom_preprocessor(raw)
   elif (key == "Book5"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        five_book = custom_preprocessor(raw)
   elif (key == "Book6"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        six_book = custom_preprocessor(raw)
   elif (key == "Book7"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        seven_book = custom_preprocessor(raw)
   elif (key == "Book8"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        eight_book = custom_preprocessor(raw)
   elif (key == "Book9"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        nine_book = custom_preprocessor(raw)
   elif (key == "Book10"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        ten_book = custom_preprocessor(raw)
   elif (key == "Book11"):
        bookLoc = filepath_dict[key]
        response = request.urlopen(bookLoc)
        raw = response.read().decode('utf-8')
        len(raw)
        eleven_book = custom_preprocessor(raw)  
   else:
       pass


##Building First Book
first_book_text = ' '.join(first_book)
fileLoc = 'b1.txt'
with open(fileLoc, 'a') as fout:
    fout.write(first_book_text)
    fout.close()

#Building Second Book
second_book_text = ' '.join(second_book)
fileLoc = 'b2.txt'
with open(fileLoc, 'a') as fout:
    fout.write(second_book_text)
    fout.close()


#Building Third Book
third_book_text = ' '.join(third_book)
fileLoc = 'b2.txt'
with open(fileLoc, 'a') as fout:
    fout.write(third_book_text)
    fout.close()
    
#Building Third Book
four_book_text = ' '.join(four_book)
fileLoc = 'b1.txt'
with open(fileLoc, 'a') as fout:
    fout.write(four_book_text)
    fout.close()
    
five_book_text = ' '.join(five_book)
fileLoc = 'b2.txt'
with open(fileLoc, 'a') as fout:
    fout.write(five_book_text)
    fout.close()
    
six_book_text = ' '.join(six_book)
fileLoc = 'b2.txt'
with open(fileLoc, 'a') as fout:
    fout.write(six_book_text)
    fout.close()
    
seven_book_text = ' '.join(seven_book)
fileLoc = 'b2.txt'
with open(fileLoc, 'a') as fout:
    fout.write(seven_book_text)
    fout.close()
    
eight_book_text = ' '.join(eight_book)
fileLoc = 'b2.txt'
with open(fileLoc, 'a') as fout:
    fout.write(eight_book_text)
    fout.close()
    
nine_book_text = ' '.join(nine_book)
fileLoc = 'b2.txt'
with open(fileLoc, 'a') as fout:
    fout.write(nine_book_text)
    fout.close()
    
ten_book_text = ' '.join(ten_book)
fileLoc = 'b2.txt'
with open(fileLoc, 'a') as fout:
    fout.write(ten_book_text)
    fout.close()
    
eleven_book_text = ' '.join(eleven_book)
fileLoc = 'b2.txt'
with open(fileLoc, 'a') as fout:
    fout.write(eleven_book_text)
    fout.close()


# labeling
# Cretaing tuple
# aBooklist = []
def readAtxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 200:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(0)
        i += 150
        n += 150
        x += 1
    return docs, labels


# Cretaing tuple
# bBooklist = []
def readBtxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 184:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(1)
        i += 150
        n += 150
        x += 1
    return docs, labels

# Cretaing tuple
# cBooklist = []
def readCtxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 200:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(2)
        i += 150
        n += 150
        x += 1
    return docs, labels

def readDtxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 184:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(1)
        i += 150
        n += 150
        x += 1
    return docs, labels

# Cretaing tuple
# bBooklist = []
def readEtxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 200:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(1)
        i += 150
        n += 150
        x += 1
    return docs, labels

# Cretaing tuple
# bBooklist = []
def readFtxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 184:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(1)
        i += 150
        n += 150
        x += 1
    return docs, labels

# Cretaing tuple
# bBooklist = []
def readGtxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 200:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(1)
        i += 150
        n += 150
        x += 1
    return docs, labels

# Cretaing tuple
# bBooklist = []
def readHtxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 184:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(1)
        i += 150
        n += 150
        x += 1
    return docs, labels

# Cretaing tuple
# bBooklist = []
def readItxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 200:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(1)
        i += 150
        n += 150
        x += 1
    return docs, labels

# Cretaing tuple
# bBooklist = []
def readJtxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 184:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(1)
        i += 150
        n += 150
        x += 1
    return docs, labels

# Cretaing tuple
# bBooklist = []
def readKtxtfile(bookText, docs, labels):
    x = 0
    i = 0
    n = 150
    while x < 200:
        temp = ""
        words = bookText.split(" ")[i:n]
        for word in words:
            temp = word + " " + temp
        docs.append(temp)
        labels.append(1)
        i += 150
        n += 150
        x += 1
    return docs, labels


docs = []
labels = []
docs, labels = readAtxtfile(first_book_text, docs, labels)
# print(aBooklist)
docs, labels = readBtxtfile(second_book_text, docs, labels)
# print(bBooklist)
docs, labels = readCtxtfile(third_book_text, docs, labels)
# print(cBooklist)
docs, labels = readDtxtfile(four_book_text, docs, labels)
# print(cBooklist)
docs, labels = readEtxtfile(five_book_text, docs, labels)
# print(aBooklist)
docs, labels = readFtxtfile(six_book_text, docs, labels)
# print(bBooklist)
docs, labels = readGtxtfile(seven_book_text, docs, labels)
# print(cBooklist)
docs, labels = readHtxtfile(eight_book_text, docs, labels)
# print(cBooklist)
docs, labels = readItxtfile(nine_book_text, docs, labels)
# print(aBooklist)
docs, labels = readJtxtfile(ten_book_text, docs, labels)
# print(bBooklist)
docs, labels = readKtxtfile(eleven_book_text, docs, labels)
# print(cBooklist)


#print(len(docs))
#print(docs)
#print(labels)
#print(len(labels))


#Tf-IDF Model Implementation
# Creating the Tf-Idf model
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(max_features = 2000, min_df = 3, max_df = 0.6)
TF_X = vectorizer.fit_transform(docs)
TF_X.toarray()
type(TF_X)



#**********************K-means*************************************************
from time import time
from sklearn import metrics
from scipy.stats import spearmanr

name = 'TFIDF'
t0 = time()

def tfidf_kmeans(TF_X,k):
    from sklearn.cluster import KMeans
    estimator = KMeans(init='k-means++', n_clusters=k, n_init=10, random_state= 0)
    #print(estimator)
    estimator.fit(TF_X)
    return estimator.labels_


#*****************************calculation**************************************
num_cluster = 11
clusters= tfidf_kmeans(TF_X, k= num_cluster)
#print(len(clusters))
#print(len(labels))


print(82 * '_')
print('init\t\ttime\thomo\tcompl\tv-meas\tARI\tAMI\tkappa\tcorr\tsilh_Clus\tsilh_HMN')
print('%-9s\t%.2fs\t%i\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f\t%-9s\t%.3f\t%.3f'
          % (name, (time() - t0),
             metrics.homogeneity_score(labels, clusters),
             metrics.completeness_score(labels, clusters),
             metrics.v_measure_score(labels, clusters),
             metrics.adjusted_rand_score(labels, clusters),
             metrics.adjusted_mutual_info_score(labels,  clusters),
             metrics.cohen_kappa_score(labels, clusters,weights='linear'),
             str(spearmanr(labels,clusters)),
             metrics.silhouette_score(TF_X, clusters,
                                      metric='euclidean'),
             metrics.silhouette_score(TF_X, labels,
                                      metric='euclidean'),
             ))

#**************************error analysis**************************************
from sklearn.metrics.cluster import contingency_matrix
x = labels #actual labels
y = clusters #predicted labels
error_analysis = contingency_matrix(x, y)
#***************************plot************************************************
from sklearn.metrics.pairwise import cosine_similarity
dist = 1 - cosine_similarity(TF_X)


import matplotlib.pyplot as plt
from sklearn.manifold import MDS
MDS()
# convert two components as we're plotting points in a two-dimensional plane
# "precomputed" because we provide a distance matrix
# we will also specify `random_state` so the plot is reproducible.
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1)
pos = mds.fit_transform(dist)  # shape (n_components, n_samples)
xs, ys = pos[:, 0], pos[:, 1]


#set up colors per clusters using a dict
cluster_colors = {0: '#1b9e77', 1: '#d95f02', 2: '#7570b3', 3: '#B87C5C', 4: '#EF5E11', 5: '#EF2811', 6: '#EF7611', 7: '#EFE111', 8: '#43EF11', 9: '#1117EF', 10: '#200420'}

#set up cluster names using a dict
cluster_names = {0: 'crime',
                 1: 'action',
                 2: 'drama',
                 3: 'horror',
                 4: 'romance',
                 5: 'fantasy',
                 6: 'family',
                 7: 'adventure',
                 8: 'thriller',
                 9: 'mystery',
                 10: 'comedy'}


#create data frame that has the result of the MDS plus the cluster numbers and titles
df = pd.DataFrame(dict(x=xs, y=ys, label=clusters))

#group by cluster
groups = df.groupby('label')


# set up plot
fig, ax = plt.subplots(figsize=(8, 5)) # set size
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling

#iterate through groups to layer the plot
for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=12,
            label=cluster_names[name], color=cluster_colors[name],
            mec='none')
    ax.set_aspect('auto')
    ax.tick_params(\
        axis= 'x',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelbottom='off')
    ax.tick_params(\
        axis= 'y',         # changes apply to the y-axis
        which='both',      # both major and minor ticks are affected
        left='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelleft='off')

ax.legend(numpoints=1)  #show legend with only 1 point
plt.show() #show the plot
# Out:
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	kappa	corr	silh_Clus	silh_HMN
# TFIDF    	0.79s	0	0.000	0.000	-0.010	-0.005	0.000	SpearmanrResult(correlation=0.0, pvalue=1.0)	0.709	-0.030
